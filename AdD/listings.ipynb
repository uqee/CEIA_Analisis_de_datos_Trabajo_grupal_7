# %%
import pandas
dataFrame = pandas.read_csv('./listings.csv')

# %%
print(dataFrame.head())
# Out:
#                     id                                               name  \
# 0             42610838  Puerto Madero a 3 cuadras, centro, bello , tea...
# 1  1305876403852901802                       Apart estudio en Microcentro
# 2  1542233033640525302      Departamento en Buenos Aires, abasto shopping
# 3  1004530078359434134                           Departamento en Recoleta
# 4   800145927121871422                            Coqueto para 4 personas
#
#      host_id      host_profile_id         host_name  neighbourhood_group  \
# 0  224049389  1469188629918707060          Gabriela                  NaN
# 1   25649070  1465347917068117288          Federico                  NaN
# 2  153014015  1468500000533080859             Marco                  NaN
# 3    1409800  1462517876404348407            Marian                  NaN
# 4  467965425  1470109782901816721  Maria Del Carmen                  NaN
#
#   neighbourhood   latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
print(dataFrame.tail())
# Out:
#                         id                                              name  \
# 27343  1587119060096878911   Estudio luminoso en el corazón de Villa Crespo.
# 27344             37623532  Modern Top located Duplex Apartment! Up to 4 pax
# 27345  1074846345919500333                       Departamento Villa crespo I
# 27346  1028342669639305203   Depto a 8 min de Palermo,subte línea B 100 Mts.
# 27347             18517386           Apartment Full Equipment  in Belgrano R
#
#          host_id      host_profile_id             host_name  \
# 27343    1534662  1462518725032785871             Florencia
# 27344    2809500  1462609256411099848             Florencia
# 27345  133597828  1462947748907784667  Estudio H Apartments
# 27346   49955010  1465763312015870684               Mariano
# 27347   57658152  1466691284640462108                  Ines
#
#        neighbourhood_group neighbourhood   latitude  longitude  \
# 27343                  NaN  Villa Crespo -34.597425 -58.442220
# ...
